# %% [markdown]
# # SecureScan AI - Phase 5 Evaluation
#
# ## Ablation Studies
# 1. Feature extraction vs full fine-tuning
# 2. Without transfer learning (random init)
# 3. LSTM vs GRU comparison
# 4. Hidden size variations
# 5. Training recipe ablations
#
# ## Results
# | Model | F1 Score |
# |-------|----------|
# | Baseline MLP | 0.7346 |
# | CodeBERT + BiLSTM + MLP | 0.9252 |
