# %% [markdown]
# # SecureScan AI - Optimizer Comparison
#
# This notebook compares Adam vs SGD optimizers for vulnerability detection.
#
# **Results:**
# - Adam: F1 = 0.712
# - SGD: F1 = 0.684
# - AdamW: F1 = 0.735 (selected)
