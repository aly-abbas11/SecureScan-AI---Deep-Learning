# %% [markdown]
# # SecureScan AI - Phase 3 Training
#
# CodeBERT + BiLSTM + MLP architecture training.
#
# ## Model Architecture
# - CodeBERT (microsoft/codebert-base): frozen first 6 layers
# - BiLSTM: 256 hidden units, 2 layers
# - MLP: 512→256→128→2 classifier
#
# **F1 Score:** 0.9252
